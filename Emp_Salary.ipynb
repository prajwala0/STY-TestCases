# %%
f = open('emp12.csv','r')

for x in f:
    row = x.split(',')
    salary = int(row[5])
    print('Total salary for ',row[1],'is ',salary)
    DA = salary*0.25
    print('DA is ', str(DA))
    TZ = salary*0.15
    print('TZ is ', str(TZ))
    HRA = salary*0.16
    print('HRA is ', str(HRA))
    LIC = salary*0.05
    print('LIC is ', str(DA))
    MA = salary*0.05
    print('MA is ', str(DA))
    Net_Sal =  DA + TZ + HRA + LIC + MA 
    print("Net salary ",row[1],"is ",Net_Sal)
    print()
# Out:
# Total salary for  Sheethal is  25000
# DA is  6250.0
# TZ is  3750.0
# HRA is  4000.0
# LIC is  6250.0
# MA is  6250.0
# Net salary  Sheethal is  16500.0
#
# Total salary for  Sonu is  28000
# DA is  7000.0
# TZ is  4200.0
# HRA is  4480.0
# LIC is  7000.0
# MA is  7000.0
# Net salary  Sonu is  18480.0
#
# Total salary for  Sandeep is  100000
# DA is  25000.0
# TZ is  15000.0
# HRA is  16000.0
# LIC is  25000.0
# MA is  25000.0
# Net salary  Sandeep is  66000.0
#
# Total salary for  Manoj is  65000
# DA is  16250.0
# TZ is  9750.0
# HRA is  10400.0
# LIC is  16250.0
# MA is  16250.0
# Net salary  Manoj is  42900.0
#
# Total salary for  Prasanna is  15000
# DA is  3750.0
# TZ is  2250.0
# HRA is  2400.0
# LIC is  3750.0
# MA is  3750.0
# Net salary  Prasanna is  9900.0
#
# Total salary for  Priyanka is  20000
# DA is  5000.0
# TZ is  3000.0
# HRA is  3200.0
# LIC is  5000.0
# MA is  5000.0
# Net salary  Priyanka is  13200.0
#
# Total salary for  Shravanthi is  28000
# DA is  7000.0
# ...
